# %%
from datetime import datetime
import pandas as pd
import numpy as np
import networkx as nx
from tqdm import tqdm
from pprint import pprint
import pickle
import heapq as heap
import sys
import math

# %%
with open('data/graph_with_loops.pkl', 'rb') as f:
    G = pickle.load(f)

with open('data/graph_without_loops.pkl', 'rb') as f:
    G_loops = pickle.load(f)

# %%
with open('data/graph_simple.pkl', 'rb') as f:
    G_simple = pickle.load(f)

# %%
with open('data/graph_total.pkl', 'rb') as f:
    G_total = pickle.load(f)

# %%
def interval_time(G, time_inter):
    '''
    :param G: initial graph, with u, v and weights and time_list as attributes
    :param time_inter: [start_date, end_date]
    :return: new_G: graph with only u, v and weight, which is the length of all
                    the dates inside the time interval
    '''
    start = time_inter[0]
    end = time_inter[1]
    new_G = nx.DiGraph()
    for u, v, data in tqdm(G.edges(data=True)):
        time_list = data['time_list']
        # leave only the dates inside the time interval
        new_time_list = [time for time in time_list if start <= time <= end]
        # new weight, which is the length of the new_time_list
        w = len(new_time_list)
        # if the weight differ from 0, then the edge exists
        if w != 0:
            new_G.add_edge(u, v, weight=w)
    return new_G

# %%
def functionality_N(params, time_inter):
    new_g = interval_time(G, time_inter)

# %%
nodes_list = list(G.nodes)
df = nx.to_pandas_edgelist(G, nodelist=nodes_list)

# %%
def in_degree(df_g, node):
    # number of edges where node is target
    return df_g[df_g['target']==node].target.count()

def out_degree(df_g, node):
    # number of edges where node is source
    return df_g[df_g['source']==node].source.count()

def degree_centrality(df_g, node, G):
    degree = in_degree(df_g, node) + out_degree(df_g, node)
    num_nodes = len(list(G.nodes))
    return degree/(num_nodes-1)

# %% [markdown]
# ## Functionality 2
# - **Betweenness**
# - **PageRank**
# - **ClosenessCentrality**
# - **DegreeCentrality** of a node v is defined as  $degree\_centrality(v) = \frac{degree(v)}{n-1} $ ,  where degree(v) is the number of neighbors of v.

# %%
def dijkstra(df, source, target, G):
    '''
    :param df: dataframe of the graph: source, target, weight
    :param source: source node
    :param target: target node
    :return: final_weight, path
    '''
    # init the distance dictionary with the source node as key and as value None (parent node) and 0 (distance)
    distance_par = {source: (None, 0)}
    visited = set()
    # store the current node
    curr_node = source

    while curr_node != target:
        visited.add(curr_node)
        dest_list = df[df['source']==curr_node].target.to_list()
        # taking only the weight of curr_node
        curr_weight = distance_par[curr_node][1]
        for node in dest_list:
            weight = G[curr_node][node]['weight'] + curr_weight
            if node not in distance_par:
                distance_par[node] = (curr_node, weight)
            else:
                node_weight = distance_par[node][1]
                if node_weight > weight:
                    distance_par[node] = (curr_node, weight)

        # create a list of nodes to visit
        next_dest_list = {n: distance_par[n] for n in distance_par if n not in visited}

        # check if there are nodes to visit
        if not next_dest_list:
            return 'No possible path'

        # next curr node is the one in next_dest_list (nodes still to visit) with the lowest weight
        curr_node = min(next_dest_list, key=lambda k: next_dest_list[k][1])

    # now we wont to compute the list of the shortest path from source to target
    short_path = []
    # at the beginning, curr_node is the target node, since the first while is finished
    final_weight = distance_par[curr_node][1]
    while curr_node is not None:
        short_path.append(curr_node)
        par_node = distance_par[curr_node][0]
        curr_node = par_node

    # reverse the list now
    short_path = short_path[::-1]

    return [final_weight, short_path]

# %%
new_g = interval_time(G_total, ["2015-08-01 ","2015-08-02"])
# 9927 nodi
# Out:
# 100%|██████████| 10300590/10300590 [00:09<00:00, 1041504.51it/s]

# %%
nodes_list = list(new_g.nodes)
df = nx.to_pandas_edgelist(new_g, nodelist=nodes_list)
df.head()
# Out:
#    source   target  weight
# 0  149341  5181076       1
# 1  149341  1391026       1
# 2  149341  5182088       1
# 3  149341  1800840       1
# 4  149341   366782       1

# %%
g = new_g.subgraph(nodes_list[800:850])

# %%
nodes_list_g = nodes_list[0:30]
dfg = nx.to_pandas_edgelist(g, nodelist=nodes_list)
dfg
# Out:
#      source   target  weight
# 0   3501958   928007       1
# 1   3501958  2581174       1
# 2   3501958  5011413       1
# 3   3501958  4795214       1
# 4   3501958  5055411       2
# 5   3501958  2403836       1
# 6    928007  3501958       1
# 7   2581174  3501958       1
# 8    418556  3988057       2
# 9    418556  4090458       2
# 10  3988057   418556       1
# 11  3956566  3919629       4
# 12  3956566  2180161       3
# 13  2180161  3956566       5
# 14    48503  1565982       1
# 15    48503  5182586       1
# 16  1565982    48503       1
# 17  4391054  5182501       1
# 18  5182501  4391054       1
# 19  2464386  2770572       4
# 20  2464386  4519059       1
# 21  2770572  2464386       1
# 22  3448419  2410148       1
# 23  3448419  4013751       1
# 24  2410148  2406926       1
# 25    52239   429002       1
# 26  4232819  4786688       1
# 27  4786688  4232819       1
# 28  4135581  4588511       5
# 29  4588511  4135581       1
# 30  5016888  1591139       1
# 31  1591139  5016888       1
# 32  2542565  2406926       1
# 33  2406926  2410148       1
# 34  2065540  1392229       1
# 35  1392229  2065540       1
# 36   895245   895795       1
# 37   895245   364100       1
# 38   895245   258961       1

# %%
# for each node v, we store the shortest paths between v and all the other nodes in new_g
# as dictionary of dictionaries
shortest_paths = {}
for v in g.nodes:
    shortest_paths[v] = {}
    for u in g.nodes:
        shortest_paths[v][u] = dijkstra(dfg, v, u, g)
        
#with open('data/shortest_paths.pkl', 'wb') as f:
    #shortest_paths = pickle.dump(shortest_paths, f)

# %%
shortest_paths
# Out:
# {4786688: {4786688: [0, [4786688]],
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: [1, [4786688, 4232819]],
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2464386: {4786688: 'No possible path',
#   2464386: [0, [2464386]],
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: [4, [2464386, 2770572]],
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: [1, [2464386, 4519059]],
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2065540: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: [0, [2065540]],
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: [1, [2065540, 1392229]],
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  3501958: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: [0, [3501958]],
#   928007: [1, [3501958, 928007]],
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: [2, [3501958, 5055411]],
#   895795: 'No possible path',
#   2581174: [1, [3501958, 2581174]],
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: [1, [3501958, 4795214]],
#   5005262: 'No possible path',
#   5011413: [1, [3501958, 5011413]],
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: [1, [3501958, 2403836]],
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  928007: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: [1, [928007, 3501958]],
#   928007: [0, [928007]],
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: [3, [928007, 3501958, 5055411]],
#   895795: 'No possible path',
#   2581174: [2, [928007, 3501958, 2581174]],
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: [2, [928007, 3501958, 4795214]],
#   5005262: 'No possible path',
#   5011413: [2, [928007, 3501958, 5011413]],
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: [2, [928007, 3501958, 2403836]],
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2770572: {4786688: 'No possible path',
#   2464386: [1, [2770572, 2464386]],
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: [0, [2770572]],
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: [2, [2770572, 2464386, 4519059]],
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  3919629: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: [0, [3919629]],
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  4391054: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: [0, [4391054]],
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: [1, [4391054, 5182501]],
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  52239: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: [0, [52239]],
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: [1, [52239, 429002]],
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2464528: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: [0, [2464528]],
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  3788176: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: [0, [3788176]],
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2406926: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: [0, [2406926]],
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: [1, [2406926, 2410148]],
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  4519059: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: [0, [4519059]],
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  895245: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: [0, [895245]],
#   258961: [1, [895245, 258961]],
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: [1, [895245, 895795]],
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: [1, [895245, 364100]],
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  258961: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: [0, [258961]],
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  3216793: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: [0, [3216793]],
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  1630618: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: [0, [1630618]],
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  4135581: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: [0, [4135581]],
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: [5, [4135581, 4588511]],
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  1565982: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: [0, [1565982]],
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: [1, [1565982, 48503]],
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: [2, [1565982, 48503, 5182586]],
#   418556: 'No possible path'},
#  4755876: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: [0, [4755876]],
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  5182501: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: [1, [5182501, 4391054]],
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: [0, [5182501]],
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2410148: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: [1, [2410148, 2406926]],
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: [0, [2410148]],
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  5055411: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: [0, [5055411]],
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  895795: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: [0, [895795]],
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2581174: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: [1, [2581174, 3501958]],
#   928007: [2, [2581174, 3501958, 928007]],
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: [3, [2581174, 3501958, 5055411]],
#   895795: 'No possible path',
#   2581174: [0, [2581174]],
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: [2, [2581174, 3501958, 4795214]],
#   5005262: 'No possible path',
#   5011413: [2, [2581174, 3501958, 5011413]],
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: [2, [2581174, 3501958, 2403836]],
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  4013751: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: [0, [4013751]],
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  5016888: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: [0, [5016888]],
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: [1, [5016888, 1591139]],
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  48503: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: [1, [48503, 1565982]],
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: [0, [48503]],
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: [1, [48503, 5182586]],
#   418556: 'No possible path'},
#  2180161: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: [9, [2180161, 3956566, 3919629]],
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: [0, [2180161]],
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: [5, [2180161, 3956566]],
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  364100: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: [0, [364100]],
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  429002: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: [0, [429002]],
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
# ...
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: [0, [4588511]],
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  162273: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: [0, [162273]],
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  3448419: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: [2, [3448419, 2410148, 2406926]],
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: [1, [3448419, 2410148]],
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: [1, [3448419, 4013751]],
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: [0, [3448419]],
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  1591139: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: [1, [1591139, 5016888]],
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: [0, [1591139]],
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  2542565: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: [1, [2542565, 2406926]],
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: [2, [2542565, 2406926, 2410148]],
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: [0, [2542565]],
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  1392229: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: [1, [1392229, 2065540]],
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: [0, [1392229]],
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  3830889: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: [0, [3830889]],
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  4232819: {4786688: [1, [4232819, 4786688]],
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: [0, [4232819]],
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  5105015: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: [0, [5105015]],
#   5182586: 'No possible path',
#   418556: 'No possible path'},
#  5182586: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: 'No possible path',
#   4090458: 'No possible path',
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: [0, [5182586]],
#   418556: 'No possible path'},
#  418556: {4786688: 'No possible path',
#   2464386: 'No possible path',
#   2065540: 'No possible path',
#   3501958: 'No possible path',
#   928007: 'No possible path',
#   2770572: 'No possible path',
#   3919629: 'No possible path',
#   4391054: 'No possible path',
#   52239: 'No possible path',
#   2464528: 'No possible path',
#   3788176: 'No possible path',
#   2406926: 'No possible path',
#   4519059: 'No possible path',
#   895245: 'No possible path',
#   258961: 'No possible path',
#   3216793: 'No possible path',
#   1630618: 'No possible path',
#   4135581: 'No possible path',
#   1565982: 'No possible path',
#   4755876: 'No possible path',
#   5182501: 'No possible path',
#   2410148: 'No possible path',
#   5055411: 'No possible path',
#   895795: 'No possible path',
#   2581174: 'No possible path',
#   4013751: 'No possible path',
#   5016888: 'No possible path',
#   48503: 'No possible path',
#   2180161: 'No possible path',
#   364100: 'No possible path',
#   429002: 'No possible path',
#   4795214: 'No possible path',
#   5005262: 'No possible path',
#   5011413: 'No possible path',
#   3956566: 'No possible path',
#   5182424: 'No possible path',
#   3988057: [2, [418556, 3988057]],
#   4090458: [2, [418556, 4090458]],
#   2403836: 'No possible path',
#   4588511: 'No possible path',
#   162273: 'No possible path',
#   3448419: 'No possible path',
#   1591139: 'No possible path',
#   2542565: 'No possible path',
#   1392229: 'No possible path',
#   3830889: 'No possible path',
#   4232819: 'No possible path',
#   5105015: 'No possible path',
#   5182586: 'No possible path',
#   418556: [0, [418556]]}}

# %%
# AGGIUNGERE INTERVALLO TEMPO IN INPUT
def BestUsers(G, v, metric):
    output = None
    #G = interval_time(G, time_inter)
    shortest_paths = {}
    for v in g.nodes:
        shortest_paths[v] = {}
        for u in g.nodes:
            shortest_paths[v][u] = dijkstra(dfg, v, u, g)
            
    if metric == "Betweenness":
        sp_total = len(shortest_paths) # all the shortest paths of node v
        paths_via_v = 0
        for target in shortest_paths.values():
            for path in target.values():
                if path != 'No possible path':
                    if v in path and path[0].all() != v and path[-1].all() != v:
                        paths_via_v += 1
        
        Betweenness = ((paths_via_v/sp_total)/math.comb(len(G.nodes)-1,2))
        output = Betweenness
    
    if metric == "PageRank":
        a = 0.15
        output = PageRank(G, a)[v]
                          
    if metric == "ClosenessCentrality":
        d = 0
        nodes = list(G.nodes).remove(v)
        for n in nodes:
            d += shortest_path(G,n,v)[1]
        Closeness = (len(G.nodes)-1)/d
        output = Closeness
    
    if metric == "DegreeCentrality":
        
        DegreeC = G.degree(v)/(len(G.nodes)-1)
        output = DegreeC  
                       
    return output

# %%
BestUsers(g, 2464386,"Betweenness")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-456-2ec857c5aef3> in <module>
# ----> 1 BestUsers(g, 2464386,"Betweenness")
#
# <ipython-input-455-f5aea8533cb5> in BestUsers(G, v, metric)
#      15             for path in target.values():
#      16                 if path != 'No possible path':
# ---> 17                     if v in path and path[0].all() != v and path[-1].all() != v:
#      18                         paths_via_v += 1
#      19
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# Given:
# - The transition matrix $P$, where the generic element $p_{ij} = Pr$(to go from node i to node j)
# - probability of teleporting $a$
# - probability vector $\vec{q^t}$, where the generic element $q_v^t = Pr$(to be in state v), in general:
# $$\begin{aligned}
# \vec{q^t} = \vec{q^{t-1}}P
# \end{aligned}$$
#
# After a high number of steps, it converges to the stationary distribution $\vec{\pi}$, corresponding to the (left) eigenvector with eigenvalue 1:
#
# $$\begin{aligned}
# \vec{\pi} = \vec{\pi}P \implies \pi_i = \sum_{j=1}^{n}\pi_jP{ji}
# \end{aligned}$$
#
# where $n$ is the number of nodes.

# %%
def PageRank(G, a):
    '''
    input:
    G = graph
    a = probability of teleporting
    
    output:
    pi_i = pagerank score of node i
    '''
    # initialize pagerank score at 1 for each node
    n = len(G.nodes)
    nodes_list = list(G.nodes)
    pi = {v:1 for v in nodes_list}
    
    # build adjacency matrix
    A = np.zeros((n, n))
    for v in nodes_list:
        for u in nodes_list:
            if (v,u) in G.edges:
                A[nodes_list.index(v),nodes_list.index(u)] += 1
    
    # add links if a node doesn't have and normalize
    for row in range(n):
        if np.all(A[row,:] == 0):
            A[row,:] == [(1/n)*n]
        
        else:
            non_zeros = 0
            for i in range(len(A)):
                for j in range(len(A[i])):
                    if A[i,j] != 0:
                        non_zeros += 1
            
            A[row,:] = np.where(A[row,:] != 0, 1/non_zeros, 0)
    
    # build P matrix
    P = (a/n)*np.ones((n, n)) + (1-a)*A
    
    for i in nodes_list:
        for j in nodes_list:
            pi[i] = pi[j]*P[nodes_list.index(j),nodes_list.index(i)]
            
    return pi

# %%
p = PageRank(g, 0.15)
sum(p.values())
# Out:
# 0.1905897705897437
